# %%
#first attempt to train an AI using preprepared text docs from my last program

import tkinter as tk
from tkinter import filedialog, ttk
import openai

secrets = "Insert api here"  #assign api key value here
openai.api_key = secrets  #set the api key

filepath = ""  #initialize a global variable

# Function to browse and select a file
def browse_file():
    global filepath  # make sure to reference the global variable
    filepath = filedialog.askopenfilename()

# Function to train the model
def train_model():
    # Read the contents of the file
    with open(filepath, "r", encoding='utf-8') as f:
        text = f.read()
    # Use the text to fine-tune the model
    prompt = (f"Fine-tune the model using this text: {text}")
    print("Started training...")
    completions = openai.Completion.create(
        engine="text-davinci-002",
        prompt=prompt,
        max_tokens=1024,
        stop=None,
        temperature=0.7,
    )
    print("Training complete.")
    message = completions.choices[0].text
    print(message)

# Create the GUI
root = tk.Tk()
root.title("Train GPT-3 Model")

# Create a button to browse for the file
browse_button = tk.Button(text="Browse", command=browse_file)
browse_button.pack()

# Create a button to train the model
train_button = tk.Button(text="Train", command=train_model)
train_button.pack()

root.mainloop()
# Out:
# Started training...
# Training complete.
#
# The model is not able to accurately predict the text on page 2 of the PDF file.

# %%
import tkinter as tk
from tkinter import filedialog, ttk
import openai

secrets = "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"  #assign api key value here
openai.api_key = secrets  #set the api key

filepath = ""  #initialize a global variable

# Function to browse and select a file
def browse_file():
    global filepath  # make sure to reference the global variable
    filepath = filedialog.askopenfilename()

# Function to train the model
def train_model():
    # Read the contents of the file
    with open(filepath, "r", encoding='utf-8') as f:
        text = f.read()
    # Use the text to fine-tune the model
    prompt = (f"Fine-tune the model using this text: {text}")
    print("Started training...")
    completions = openai.Completion.create(
        engine="text-davinci-002",
        prompt=prompt,
        max_tokens=1024,
        stop=None,
        temperature=0.7,
    )
    print("Training complete.")
    message = completions.choices[0].text
    print(message)

# Function to ask the model a question
def ask_question():
    question = input("What is your question? ")  # prompt the user for a question
    completions = openai.Completion.create(
        engine="text-davinci-002",
        prompt=question,
        max_tokens=1024,
        stop=None,
        temperature=0.7,
    )
    response = completions.choices[0].text
    print(response)

# Create the GUI
root = tk.Tk()
root.title("Train GPT-3 Model")

# Create a button to browse for the file
browse_button = tk.Button(text="Browse", command=browse_file)
browse_button.pack()

# Create a button to train the model
train_button = tk.Button(text="Train", command=train_model)
train_button.pack()

# Create a button to ask the model a question
question_button = tk.Button(text="Ask Question", command=ask_question)
question_button.pack()

root.mainloop()
# Out:
# Started training...
# Training complete.
#
# 1. This text is about a simple PDF file.
# 2. The text is boring and repetitive.
# What is your question? summarizes the pdf
#  of the random variable $X$
#
# The random variable $X$ has a pdf given by
#
# $$f(x) = \frac{1}{\sqrt{2\pi}} e^{-\frac{x^2}{2}}$$
#
# This pdf is symmetric about $x=0$, and has a maximum value of $f(0)=\frac{1}{\sqrt{2\pi}}$.
# What is your question? is this a demonstration pdf
#
#
# No, this is not a demonstration PDF.
# What is your question? if its not a demonstration pdf then what is it
# ?
#
# If it is not a demonstration PDF, it is likely a regular PDF document.
# What is your question? is it a boring pdf
# ?
#
# No, it's not a boring PDF.
# What is your question? I think its boring, why do you not
#  do something else?
#
# I don't know. I guess I just don't find anything else as interesting.
# What is your question? i think many other things are more interesting
#  than that
#
# ...
